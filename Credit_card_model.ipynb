# %% [markdown]
# <a href="https://colab.research.google.com/github/rahamathullahja/project_1/blob/main/Credit_card_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING DEPENDENCIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
credit1=pd.read_csv('/content/fraudTest.csv')
credit2=pd.read_csv('/content/fraudTrain.csv')

# %%
credit3=pd.concat([credit1, credit2], ignore_index=True)

# %% [markdown]
# COMBINED DATAFRAME

# %%
credit3.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
credit3.tail()
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 35054       15588   2019-01-10 00:19:11     4836998673805450
# 35055       15589   2019-01-10 00:20:34     6538891242532018
# 35056       15590   2019-01-10 00:21:08     6011603272871604
# 35057       15591   2019-01-10 00:21:25  4210078554961359092
# 35058       15592   2019-01-10 00:22:39     6011329966782895
#
#                                      merchant       category     amt    first  \
# 35054                      fraud_Rau and Sons    grocery_pos  209.38    Susan
# 35055                 fraud_McGlynn-Jaskolski       misc_pos   28.14     Jodi
# 35056                      fraud_Torp-Labadie  gas_transport   37.12   Robert
# 35057                     fraud_Stracke-Lemke    grocery_pos  144.65  Valerie
# 35058  fraud_Johnson, Runolfsdottir and Mayer       misc_net    4.90   Lauren
#
#             last gender                     street  ...      lat      long  \
# ...

# %% [markdown]
# FULL DATASET

# %%
credit3
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 0               0   2020-06-21 12:14:25     2291163933867244
# 1               1   2020-06-21 12:14:33     3573030041201292
# 2               2   2020-06-21 12:14:53     3598215285024754
# 3               3   2020-06-21 12:15:15     3591919803438423
# 4               4   2020-06-21 12:15:17     3526826139003047
# ...           ...                   ...                  ...
# 35054       15588   2019-01-10 00:19:11     4836998673805450
# 35055       15589   2019-01-10 00:20:34     6538891242532018
# 35056       15590   2019-01-10 00:21:08     6011603272871604
# 35057       15591   2019-01-10 00:21:25  4210078554961359092
# 35058       15592   2019-01-10 00:22:39     6011329966782895
#
#                                      merchant        category     amt  \
# 0                       fraud_Kirlin and Sons   personal_care    2.86
# 1                        fraud_Sporer-Keebler   personal_care   29.84
# ...

# %% [markdown]
# CHECKING FOR MISSING VALUES

# %%
df[credit3.isnull()]
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     1
# state                    1
# zip                      1
# lat                      1
# long                     1
# city_pop                 1
# job                      1
# dob                      1
# trans_num                1
# unix_time                1
# merch_lat                1
# merch_long               2
# is_fraud                 2
# dtype: int64

# %%
#number of rows and columns
credit3.shape
# Out:
# (35059, 23)

# %% [markdown]
# TARGET FEATURE

# %%
credit3['is_fraud'].value_counts()
# Out:
# 0.0    34889
# 1.0      168
# Name: is_fraud, dtype: int64

# %% [markdown]
# THE DATASET IS IMBALANCED
#
# legit value == 0 fraud value == 1

# %%
legit=credit3[credit3.is_fraud==0]
fraud=credit3[credit3.is_fraud==1]

# %%
legit.amt.describe()

# %%
fraud.amt.describe()

# %%
credit3.drop(['merchant','first','last','gender','street','city','state','lat','long','dob','merch_lat','merch_long'],axis=1,inplace=True)

# %%
labels=LabelEncoder()
labels1=labels.fit_transform(credit3.trans_date_trans_time)
credit3['trans_date_trans_time']=labels1
labels2=labels.fit_transform(credit3.category)
credit3['category']=labels2
labels3=labels.fit_transform(credit3.job)
credit3['job']=labels3
labels4=labels.fit_transform(credit3.trans_num)
credit3['trans_num']=labels4
credit3

# %%
credit3

# %% [markdown]
# COMPARING AND VERIFYING

# %%
credit3.groupby('is_fraud').mean()

# %% [markdown]
# SAMPLE DATASET
#
# no of frauds=9651 no of legit=1842743

# %%
legitdata=legit.sample(n=9651)
credit=pd.concat([legitdata,fraud],axis=0)
credit['is_fraud'].value_counts()

# %% [markdown]
# VERIFICATION

# %%
credit.groupby('is_fraud').mean()

# %%
credit.drop(['merchant','first','last','gender','street','city','state','lat','long','dob','merch_lat','merch_long'],axis=1,inplace=True)

# %%
Labels=LabelEncoder()
Labels1=Labels.fit_transform(credit.trans_date_trans_time)
credit['trans_date_trans_time']=Labels1
Labels2=Labels.fit_transform(credit.category)
credit['category']=Labels2
Labels3=labels.fit_transform(credit.job)
credit['job']=Labels3
Labels4=labels.fit_transform(credit.trans_num)
credit['trans_num']=Labels4
credit

# %%
x=credit.drop(columns='is_fraud',axis=1)
y=credit['is_fraud']
x

# %%
y

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify =y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train

# %%
x_test=scaler.fit_transform(x_test)
x_test

# %% [markdown]
# LOGISTIC REGRESSION

# %%
model=LogisticRegression()
model.fit(x_train,y_train)

# %%
pred1=model.predict(x_test)
accuracy_score(y_test,pred1)

# %%
from sklearn import svm
svm=svm.SVC()
svm.fit(x_train,y_train)

# %%
pred2=svm.predict(x_train)
accuracy_score(pred2,y_train)

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(x_train,y_train)

# %%
pred3=RF.predict(x_test)
accuracy_score(y_test,pred3)

# %%
rom sklearn.ensemble import GradientBoostingClassifier
GBC=GradientBoostingClassifier()
GBC.fit(x_train,y_train)

# %%
pred4=GBC.predict(x_test)
accuracy_score(y_test,pred4)

# %%
print("LOGISTIC REGRESSION",accuracy_score(y_test,pred1))
print("SVC",accuracy_score(pred2,y_train))
print("RANDOM FOREST",accuracy_score(y_test,pred3))
print("GRADIENT CLASSIFICATION",accuracy_score(y_test,pred4))
