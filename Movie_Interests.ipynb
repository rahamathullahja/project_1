# %%
import pandas as pd
movies=pd.read_csv('/content/Movie Interests.csv')
movies
# Out:
#     Age  Gender   Interest
# 0     8       1  Animation
# 1    11       1  Animation
# 2    12       1  Animation
# 3    16       1     Action
# 4    18       1     Action
# 5    19       1     Action
# 6    23       1      Drama
# 7    26       1      Drama
# 8    27       1      Drama
# 9     7       0  Animation
# 10    9       0  Animation
# 11   10       0  Animation
# 12   26       0     Action
# 13   27       0     Action
# 14   30       0     Action
# 15   31       0      Drama
# 16   34       0      Drama
# 17   35       0      Drama

# %%
movies.head(5)
# Out:
#    Age  Gender   Interest
# 0    8       1  Animation
# 1   11       1  Animation
# 2   12       1  Animation
# 3   16       1     Action
# 4   18       1     Action

# %%
movies.tail(5)
# Out:
#     Age  Gender Interest
# 13   27       0   Action
# 14   30       0   Action
# 15   31       0    Drama
# 16   34       0    Drama
# 17   35       0    Drama

# %%
input=movies.drop(columns='Interest')
input
# Out:
#     Age  Gender
# 0     8       1
# 1    11       1
# 2    12       1
# 3    16       1
# 4    18       1
# 5    19       1
# 6    23       1
# 7    26       1
# 8    27       1
# 9     7       0
# 10    9       0
# 11   10       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
output=movies['Interest']
output
# Out:
# 0     Animation
# 1     Animation
# 2     Animation
# 3        Action
# 4        Action
# 5        Action
# 6         Drama
# 7         Drama
# 8         Drama
# 9     Animation
# 10    Animation
# 11    Animation
# 12       Action
# 13       Action
# 14       Action
# 15        Drama
# 16        Drama
# 17        Drama
# Name: Interest, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(input,output)
model.predict([[5,1],[23,1],[33,0],[12,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Animation', 'Drama', 'Drama', 'Animation'], dtype=object)
